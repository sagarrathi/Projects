# %%
# !ls
# Out:
# ch1_basics.ipynb  ch2_data.ipynb  Untitled.ipynb

# %%
# !ls ../Data
# Out:
# acc.csv		       Lung Cap_Random.csv
# ACC_matched.xlsx       Lung Cap_Random_csv.csv
# agri		       mid_term
# Autos.xlsx	       New Microsoft Excel Worksheet.xlsx
# Crude_Futures.csv      Regression_TCS.csv
# Crude_spot.csv	       RELIANCE_Bhavcopy_xls.xls
# Data.csv	       RELIANCE_Bhavcopy_xlsx.xlsx
# Data File.csv	       RELIANCE_close price.csv
# Data File.xlsx	       RELIANCE_number of trades.csv
# Data_for_Agri.zip      RELIANCE_trade quantity.csv
# Data_for_mid-term.zip  sddg.xlsx
# Data.xlsx	       TCS.csv
# Lung Cap_Random2.csv

# %%
import pandas as pd

# %%
df=pd.read_excel("../Data/Autos.xlsx", sheet_name="Data")

# %%
df.head()
# Out:
#    Year  Quarter   Sales   GNP  Unemp   Int   Q1   Q2   Q3  LagGNP  LagUnemp  \
# 0    79        1     NaN  2541    5.9   9.4  NaN  NaN  NaN     NaN       NaN
# 1    79        2  2910.0  2640    5.7   9.4  0.0  1.0  0.0  2541.0       5.9
# 2    79        3  2562.0  2595    5.9   9.7  0.0  0.0  1.0  2640.0       5.7
# 3    79        4  2385.0  2701    6.0  11.9  0.0  0.0  0.0  2595.0       5.9
# 4    80        1  2520.0  2785    6.2  13.4  1.0  0.0  0.0  2701.0       6.0
#
#    LagInt
# 0     NaN
# 1     9.4
# 2     9.4
# 3     9.7
# 4    11.9

# %%
df.drop(0)
# Out:
#     Year  Quarter   Sales   GNP  Unemp   Int   Q1   Q2   Q3  LagGNP  LagUnemp  \
# 1     79        2  2910.0  2640    5.7   9.4  0.0  1.0  0.0  2541.0       5.9
# 2     79        3  2562.0  2595    5.9   9.7  0.0  0.0  1.0  2640.0       5.7
# 3     79        4  2385.0  2701    6.0  11.9  0.0  0.0  0.0  2595.0       5.9
# 4     80        1  2520.0  2785    6.2  13.4  1.0  0.0  0.0  2701.0       6.0
# 5     80        2  2142.0  2509    7.3   9.6  0.0  1.0  0.0  2785.0       6.2
# 6     80        3  2130.0  2570    7.7   9.2  0.0  0.0  1.0  2509.0       7.3
# 7     80        4  2190.0  2667    7.4  13.6  0.0  0.0  0.0  2570.0       7.7
# 8     81        1  2370.0  2878    7.4  14.4  1.0  0.0  0.0  2667.0       7.4
# 9     81        2  2208.0  2835    7.4  15.3  0.0  1.0  0.0  2878.0       7.4
# 10    81        3  2196.0  2897    7.4  15.1  0.0  0.0  1.0  2835.0       7.4
# 11    81        4  1758.0  2744    8.3  11.8  0.0  0.0  0.0  2897.0       7.4
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Sales', 'GNP', 'Unemp', 'Int', 'Q1', 'Q2', 'Q3',
#        'LagGNP', 'LagUnemp', 'LagInt'],
#       dtype='object')

# %%
X=df[['Q1', 'Q2', 'Q3','LagGNP', 'LagUnemp', 'LagInt']]

# %%
y=df[["Sales"]]

# %%
import statsmodels.api as sm

# %%
est = sm.OLS(y, X, missing="drop").fit()

# %%
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     301.8
# Date:                Tue, 23 Apr 2019   Prob (F-statistic):           4.54e-22
# Time:                        13:32:47   Log-Likelihood:                -219.46
# No. Observations:                  31   AIC:                             450.9
# Df Residuals:                      25   BIC:                             459.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Q1           216.5414    165.374      1.309      0.202    -124.054     557.136
# ...
