# %%
# %load ../import.py
import quandl
quandl.ApiConfig.api_key = 'MBMzvkxtv63KjFEV-tL6'
from quandl.errors.quandl_error import NotFoundError

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from sklearn import linear_model

import ipywidgets as widgets 
from ipywidgets import  interact, interactive, fixed, interact_manual
from IPython.display import display

#####################################################################################
# From tensorflow includes
import math
from matplotlib import cm
from matplotlib import gridspec
# from matplotlib import pyplot as plt

from sklearn import metrics
import tensorflow as tf
from tensorflow.python.data import Dataset


# For elongating day 
from datetime import timedelta

# %%
s_list=pd.read_csv("../sector_list.csv")

# %%
d1_col=['Date','Ticker','Open','High','Low','Last','Close',
                         'Total Trade Quantity','Turnover (Lacs)']
d2_col=['Date','Value','Tick','R','Period']


def select_sector(sector_name):    
    price_file="../Price/Data/"+sector_name+".csv"
    ratio_file="../Ratio/Data/"+sector_name+".csv"
    
    d1=pd.read_csv(str(price_file), names=d1_col, header=None, parse_dates=['Date'])
    d2=pd.read_csv(str(ratio_file), names=d2_col, header=None, parse_dates=['Date'])
    
    d1=d1[1:]
    
    
    return [d1,d2]

sector_value=widgets.Dropdown(
                            options=s_list['sector'], 
                            description="Sector:"
                            )
w=widgets.interactive(select_sector, sector_name=sector_value)
display(w)
# Out:
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KERyb3Bkb3duKGRlc2NyaXB0aW9uPXUnU2VjdG9yOicsIG9wdGlvbnM9KCdBR1JPX0lOUFVUUycsICdBVVRPTU9CSUxFUycsICdBVVRPX0FOQ0lMTEFSSUXigKY=

# %% [markdown]
# ## 1. Creating panel p1 for prices

# %%
d1=w.result[0]
d2=w.result[1]

d1=d1[~d1.duplicated()]
d2=d2[~d2.duplicated()]

# %%
d1.head()
# Out:
#         Date    Ticker     Open    High      Low    Last    Close  \
# 1 2006-08-21  NSE/ABAN  1249.85  1275.9  1201.05  1224.0  1224.00
# 2 2006-08-22  NSE/ABAN  1245.00  1249.0  1190.00  1200.0  1199.15
# 3 2006-08-23  NSE/ABAN  1212.00  1216.0  1191.40  1208.0  1200.35
# 4 2006-08-24  NSE/ABAN  1200.05  1295.0  1190.05  1286.0  1280.80
# 5 2006-08-25  NSE/ABAN  1218.00  1310.0  1218.00  1274.0  1266.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 1              135333.0          1698.79
# 2               53138.0           643.58
# 3               39103.0           470.01
# 4              298335.0          3768.50
# 5               58259.0           741.58

# %%
d2["Ticker"]="NSE/"+d2["Tick"]
d2["Ratio"]=d2["R"]+"_"+d2["Period"]
d2.head()
# Out:
#         Date    Value        Tick       R Period          Ticker     Ratio
# 0 2012-12-31  84874.0  WALCHANNAG  BSEVOL      Q  NSE/WALCHANNAG  BSEVOL_Q
# 1 2013-03-31  83801.0  WALCHANNAG  BSEVOL      Q  NSE/WALCHANNAG  BSEVOL_Q
# 2 2013-06-30  27922.0  WALCHANNAG  BSEVOL      Q  NSE/WALCHANNAG  BSEVOL_Q
# 3 2013-09-30   7918.0  WALCHANNAG  BSEVOL      Q  NSE/WALCHANNAG  BSEVOL_Q
# 4 2013-12-31  21940.0  WALCHANNAG  BSEVOL      Q  NSE/WALCHANNAG  BSEVOL_Q

# %%
d1_date=d1['Date'].unique()
d1_date.sort()
minor_axis=list(d1.columns[2:])
minor_axis.append("Return")
p1=pd.Panel(major_axis=d1_date, minor_axis= minor_axis)

# %%
for t in d1["Ticker"].unique():
    
    p1_data=d1.loc[d1['Ticker']==t]
    del p1_data["Ticker"]
        
    p1_data.set_index('Date', inplace=True)    
    
    # shift moves dates back by 1. and calc returns on closing price
    p1_data.loc[:, "Return"]=p1_data[["Close"]].apply( lambda x: np.log( x/x.shift(1) ) )    
    
    p1[t]=p1_data

p1
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 131 (items) x 3733 (major_axis) x 8 (minor_axis)
# Items axis: NSE/ABAN to NSE/TNTELE
# Major_axis axis: 2003-04-15 00:00:00 to 2018-04-13 00:00:00
# Minor_axis axis: Open to Return

# %%
p1[t].head()
# Out:
#              Open   High   Low  Last  Close  Total Trade Quantity  \
# 2003-04-15  10.00  10.00  8.90  8.90   9.00                 316.0
# 2003-04-16   9.05   9.35  8.50  9.35   8.60                1861.0
# 2003-04-17   8.40   8.50  8.00  8.25   8.25                3800.0
# 2003-04-21   8.55   9.35  8.30  9.30   9.10                4745.0
# 2003-04-22   9.25   9.90  8.85  9.50   9.50                1987.0
#
#             Turnover (Lacs)    Return
# 2003-04-15             0.03       NaN
# 2003-04-16             0.16 -0.045462
# 2003-04-17             0.31 -0.041549
# 2003-04-21             0.42  0.098061
# 2003-04-22             0.18  0.043017

# %%
d2_date=d2['Date'].unique()
d2_date.sort()
p2=pd.Panel(major_axis=d2_date, minor_axis=d2["Ratio"].unique())

# %%
for t in d2["Ticker"].unique():
    
    p2_data=d2[d2["Ticker"]==t]
    
    del p2_data['Ticker']
    del p2_data['Tick']
    
    p2_data=p2_data.pivot_table(index="Date", columns="Ratio", values="Value")
   
    p2_data.sort_index()
    
    p2[t]=p2_data
    
p2
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 123 (items) x 24 (major_axis) x 34 (minor_axis)
# Items axis: NSE/WALCHANNAG to NSE/VGUARD
# Major_axis axis: 2012-06-30 00:00:00 to 2018-03-31 00:00:00
# Minor_axis axis: BSEVOL_Q to TI_Q

# %% [markdown]
# ## Merge only if both p and p2 are avialble as one is from NSE and other is from D'Market

# %%
items=p1.items.intersection(p2.items)
print("P1 Total Item :{0}".format(len(p1.items)) )
print("P2 Total Item :{0}".format(len(p2.items)) )
print("P3 Total Item :{0}".format(len(items)) )
# Out:
# P1 Total Item :131
# P2 Total Item :123
# P3 Total Item :123

# %%
p3_index_list = list(p1.major_axis) + list(p2.major_axis) 
p3_index_list=set(p3_index_list)
p3_index_list=list(p3_index_list)
p3_index_list.sort()

p3_index=pd.date_range(min(p3_index_list), max(p3_index_list), freq="1d")

p3_col   = list(p1.minor_axis) + list(p2.minor_axis)

# %%
p3=pd.Panel(major_axis=p3_index_list, minor_axis=p3_col)
p3
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 0 (items) x 3741 (major_axis) x 42 (minor_axis)
# Items axis: None
# Major_axis axis: 2003-04-15 00:00:00 to 2018-04-13 00:00:00
# Minor_axis axis: Open to TI_Q

# %%
for item in items: 
   
    p1_data=p1[item]
    p2_data=p2[item]
    
    p3_data=pd.merge(p1_data,p2_data, how="outer", left_index=True, right_index=True)
    
    p3[item]=p3_data
    
p3
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 123 (items) x 3741 (major_axis) x 42 (minor_axis)
# Items axis: NSE/ABAN to NSE/TNTELE
# Major_axis axis: 2003-04-15 00:00:00 to 2018-04-13 00:00:00
# Minor_axis axis: Open to TI_Q

# %% [markdown]
# ## Remove past years with no finaincal data

# %%
test=p3[p3.items[0]]
test[test.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Last, Close, Total Trade Quantity, Turnover (Lacs), Return, BSEVOL_Q, EQCAP_Q, EBIDTSH_Q, REVSH_Q, ETR_Q, MCAP_Q, OP1Q_Q, NI1Q_Q, OPMSH_Q, EBIDT1Q_Q, PBT_Q, PBDT_Q, OPSH1Q_Q, DIVSH_Q, NP_Q, DIV_PCT_Q, EPS1Q_Q, OI_Q, INT_Q, SR_Q, BSEH_Q, OEXPNS_Q, SHARE_Q, BSEC_Q, TAX_Q, BSEO_Q, FV_Q, OP_Q, DEP_Q, EBIDTSH1Q_Q, EBIDT_Q, EPS_Q, BSEL_Q, TI_Q]
# Index: []
#
# [0 rows x 42 columns]

# %%
# p3.reindex(major_axis=p3_index)
drop_min= p1.major_axis.min()
drop_max= p2.major_axis.min()
drop_range=pd.date_range(drop_min, drop_max, freq="1d")
p3
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 123 (items) x 3741 (major_axis) x 42 (minor_axis)
# Items axis: NSE/ABAN to NSE/TNTELE
# Major_axis axis: 2003-04-15 00:00:00 to 2018-04-13 00:00:00
# Minor_axis axis: Open to TI_Q

# %%
p3=p3.loc[:,drop_max:,:]
p3[p3.items[1]]["BSEVOL_Q"].unique()
# Out:
# array([          nan, 5.1970000e+03, 7.7260000e+03, 4.0335000e+04,
#        8.6300000e+03, 1.3834000e+04, 9.3122000e+04, 1.0728000e+04,
#        9.8030000e+03, 4.1909000e+04, 1.1441000e+04, 5.8480000e+03,
#        3.9160000e+03, 3.5410000e+03, 1.9860000e+04, 4.5450000e+03,
#        3.2450000e+03, 1.5880000e+03, 1.5897000e+04, 4.7640000e+03,
#        4.8190000e+03, 8.6356691e+07])

# %%
#  Adding 7 days here for prediction

# nmber of dates to ad: 

min_date=min(p3.major_axis)
max_date=max(p3.major_axis)
idx=pd.date_range(min_date, max_date)
idx
p3.reindex(major_axis=idx)
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 123 (items) x 2114 (major_axis) x 42 (minor_axis)
# Items axis: NSE/ABAN to NSE/TNTELE
# Major_axis axis: 2012-06-30 00:00:00 to 2018-04-13 00:00:00
# Minor_axis axis: Open to TI_Q

# %% [markdown]
# ### Find firms inactive for 30 days

# %%
p3[p3.items[0]]
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# 2012-06-30     NaN     NaN     NaN     NaN     NaN                   NaN
# 2012-07-02  391.00  401.70  386.05  393.00  394.35              901205.0
# 2012-07-03  395.80  401.95  392.10  395.00  396.05              570933.0
# 2012-07-04  398.00  411.95  398.00  405.50  407.15             1210606.0
# 2012-07-05  405.70  424.80  402.50  422.00  422.70             1507657.0
# 2012-07-06  422.80  425.75  412.05  413.70  414.85              811210.0
# 2012-07-09  411.95  413.80  403.50  406.30  407.30              646599.0
# 2012-07-10  408.00  423.90  406.95  419.20  421.15             1066862.0
# 2012-07-11  419.00  430.40  416.85  420.50  421.15             1034761.0
# 2012-07-12  405.15  423.40  405.15  415.20  417.60              660731.0
# 2012-07-13  420.00  432.00  418.50  426.00  428.00             1227021.0
# 2012-07-16  426.00  432.75  416.40  417.85  420.30             1191864.0
# 2012-07-17  422.00  428.00  412.95  414.00  415.65              890952.0
# 2012-07-18  413.90  418.90  402.30  415.00  416.40             1088761.0
# 2012-07-19  418.25  422.65  414.25  414.90  416.15              591691.0
#             Turnover (Lacs)    Return  BSEVOL_Q  EQCAP_Q  ...   TAX_Q  BSEO_Q  \
# 2012-06-30              NaN       NaN       NaN      NaN  ...     NaN     NaN
# 2012-07-02          3567.37  0.011733       NaN      NaN  ...     NaN     NaN
# 2012-07-03          2264.21  0.004302       NaN      NaN  ...     NaN     NaN
# 2012-07-04          4936.54  0.027641       NaN      NaN  ...     NaN     NaN
# 2012-07-05          6287.99  0.037481       NaN      NaN  ...     NaN     NaN
# 2012-07-06          3386.68 -0.018746       NaN      NaN  ...     NaN     NaN
# 2012-07-09          2641.64 -0.018367       NaN      NaN  ...     NaN     NaN
# 2012-07-10          4439.81  0.033439       NaN      NaN  ...     NaN     NaN
# 2012-07-11          4398.95  0.000000       NaN      NaN  ...     NaN     NaN
# 2012-07-12          2768.56 -0.008465       NaN      NaN  ...     NaN     NaN
# 2012-07-13          5221.43  0.024599       NaN      NaN  ...     NaN     NaN
# 2012-07-16          5086.90 -0.018154       NaN      NaN  ...     NaN     NaN
# 2012-07-17          3753.78 -0.011125       NaN      NaN  ...     NaN     NaN
# 2012-07-18          4476.85  0.001803       NaN      NaN  ...     NaN     NaN
# 2012-07-19          2474.23 -0.000601       NaN      NaN  ...     NaN     NaN
# 2012-07-20          2312.94 -0.008204       NaN      NaN  ...     NaN     NaN
# 2012-07-23          1925.32 -0.036893       NaN      NaN  ...     NaN     NaN
# 2012-07-24          2165.87 -0.015070       NaN      NaN  ...     NaN     NaN
# 2012-07-25          2834.36 -0.025720       NaN      NaN  ...     NaN     NaN
# 2012-07-26          3049.51 -0.060862       NaN      NaN  ...     NaN     NaN
# 2012-07-27          1892.22  0.024194       NaN      NaN  ...     NaN     NaN
# 2012-07-30          1436.13  0.020833       NaN      NaN  ...     NaN     NaN
# 2012-07-31          1886.06  0.014394       NaN      NaN  ...     NaN     NaN
# 2012-08-01          3045.81  0.021531       NaN      NaN  ...     NaN     NaN
# 2012-08-02          2113.45 -0.002441       NaN      NaN  ...     NaN     NaN
# 2012-08-03          1886.04  0.002184       NaN      NaN  ...     NaN     NaN
# 2012-08-06          2138.24  0.007926       NaN      NaN  ...     NaN     NaN
# 2012-08-07          1709.09 -0.004467       NaN      NaN  ...     NaN     NaN
# 2012-08-08          5764.65  0.008280       NaN      NaN  ...     NaN     NaN
# 2012-08-09          2403.36 -0.002159       NaN      NaN  ...     NaN     NaN
# ...                     ...       ...       ...      ...  ...     ...     ...
# 2018-03-01           917.03 -0.005293       NaN      NaN  ...     NaN     NaN
# 2018-03-05           758.42 -0.016947       NaN      NaN  ...     NaN     NaN
# 2018-03-06          1051.16 -0.013889       NaN      NaN  ...     NaN     NaN
# 2018-03-07           959.12 -0.034017       NaN      NaN  ...     NaN     NaN
# 2018-03-08           995.38 -0.014895       NaN      NaN  ...     NaN     NaN
# 2018-03-09          1038.99  0.000638       NaN      NaN  ...     NaN     NaN
# 2018-03-12           713.81  0.005410       NaN      NaN  ...     NaN     NaN
# 2018-03-13          2771.51  0.035846       NaN      NaN  ...     NaN     NaN
# 2018-03-14          1472.48  0.004887       NaN      NaN  ...     NaN     NaN
# 2018-03-15          1102.91  0.006681       NaN      NaN  ...     NaN     NaN
# 2018-03-16           766.20 -0.018019       NaN      NaN  ...     NaN     NaN
# 2018-03-19           721.05 -0.022123       NaN      NaN  ...     NaN     NaN
# 2018-03-20           911.88 -0.006321       NaN      NaN  ...     NaN     NaN
# 2018-03-21          1564.07  0.022261       NaN      NaN  ...     NaN     NaN
# 2018-03-22          4087.93  0.020259       NaN      NaN  ...     NaN     NaN
# 2018-03-23          1185.59 -0.039987       NaN      NaN  ...     NaN     NaN
# 2018-03-26          2191.32  0.028988       NaN      NaN  ...     NaN     NaN
# 2018-03-27          1391.56  0.005209       NaN      NaN  ...     NaN     NaN
# 2018-03-28           876.63 -0.032301       NaN      NaN  ...     NaN     NaN
# 2018-03-31              NaN       NaN       NaN      NaN  ...     NaN     NaN
# 2018-04-02           991.16  0.019382       NaN      NaN  ...     NaN     NaN
# 2018-04-03          1363.66  0.009245       NaN      NaN  ...     NaN     NaN
# 2018-04-04          1419.24 -0.020766       NaN      NaN  ...     NaN     NaN
# 2018-04-05           782.97  0.015538       NaN      NaN  ...     NaN     NaN
# 2018-04-06          1197.44  0.007679       NaN      NaN  ...     NaN     NaN
# 2018-04-09          9068.72  0.080231       NaN      NaN  ...     NaN     NaN
# 2018-04-10          2504.68 -0.020255       NaN      NaN  ...     NaN     NaN
# 2018-04-11         11539.77  0.037335       NaN      NaN  ...     NaN     NaN
# 2018-04-12          4432.90  0.006089       NaN      NaN  ...     NaN     NaN
# 2018-04-13          2079.09 -0.020349       NaN      NaN  ...     NaN     NaN
#
#             FV_Q  OP_Q  DEP_Q  EBIDTSH1Q_Q  EBIDT_Q  EPS_Q  BSEL_Q  TI_Q
# 2012-06-30   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-02   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-03   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-04   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-05   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-06   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-09   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-10   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-11   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-12   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-13   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-16   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-17   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-18   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-19   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-20   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-23   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-24   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-25   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-26   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-27   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-30   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-31   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-08-01   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-08-02   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-08-03   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-08-06   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-08-07   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-08-08   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-08-09   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# ...          ...   ...    ...          ...      ...    ...     ...   ...
# 2018-03-01   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-05   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-06   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-07   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-08   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-09   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-12   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-13   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-14   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-15   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-16   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-19   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-20   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-21   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-22   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-23   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-26   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-27   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-28   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-03-31   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-02   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-03   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-04   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-05   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-06   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-09   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-10   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-11   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-12   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2018-04-13   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
#
# [1439 rows x 42 columns]

# %%
inactive=[]

for i in p3.items: 
    data=p3[i]
    
    delisted_days = sum(pd.isnull(data['Close']))
    
    if delisted_days > 30 :   
        print("Firm:{0} is inactive for: {1}".format(i,delisted_days))
        inactive.append(i)
# Out:
# Firm:NSE/AHMEDFORGE is inactive for: 720
# Firm:NSE/APLAB is inactive for: 1179
# Firm:NSE/ASAL is inactive for: 172
# Firm:NSE/BATLIBOI is inactive for: 1439
# Firm:NSE/BHARTISHIP is inactive for: 792
# Firm:NSE/BIMETAL is inactive for: 1005
# Firm:NSE/BIRLAERIC is inactive for: 813
# Firm:NSE/CENTUM is inactive for: 160
# Firm:NSE/CORDSCABLE is inactive for: 203
# Firm:NSE/CROMPGREAV is inactive for: 281
# Firm:NSE/DENORA is inactive for: 200
# Firm:NSE/DYNAMATECH is inactive for: 151
# Firm:NSE/EIMCOELECO is inactive for: 506
# Firm:NSE/FAGBEARING is inactive for: 182
# Firm:NSE/FEDDERLOYD is inactive for: 216
# Firm:NSE/GISOLUTION is inactive for: 1174
# Firm:NSE/GKWLIMITED is inactive for: 214
# Firm:NSE/GTOFFSHORE is inactive for: 191
# Firm:NSE/HINDDORROL is inactive for: 77
# Firm:NSE/HMT is inactive for: 146
# Firm:NSE/IFGLREFRAC is inactive for: 152
# Firm:NSE/INDIANCARD is inactive for: 90
# Firm:NSE/INDLMETER is inactive for: 229
# Firm:NSE/KALINDEE is inactive for: 299
# Firm:NSE/KIRLOSIND is inactive for: 138
# Firm:NSE/LAKPRE is inactive for: 244
# Firm:NSE/LGBBROSLTD is inactive for: 137
# Firm:NSE/LLOYDELENG is inactive for: 212
# Firm:NSE/MANUGRAPH is inactive for: 139
# Firm:NSE/PANCARBON is inactive for: 1034
# Firm:NSE/PITTILAM is inactive for: 137
# Firm:NSE/PSL is inactive for: 60
# Firm:NSE/REVATHI is inactive for: 241
# Firm:NSE/RKFORGE is inactive for: 87
# Firm:NSE/SGFL is inactive for: 1064
# Firm:NSE/STERTOOLS is inactive for: 214
# Firm:NSE/TIIL is inactive for: 138
# Firm:NSE/WENDT is inactive for: 139
# Firm:NSE/ELECTHERM is inactive for: 202
# Firm:NSE/KALYANIFRG is inactive for: 665
# Firm:NSE/TNTELE is inactive for: 855

# %%
p3=p3.drop(inactive, axis=0)

# %%
p3
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 82 (items) x 1439 (major_axis) x 42 (minor_axis)
# Items axis: NSE/ABAN to NSE/ZICOM
# Major_axis axis: 2012-06-30 00:00:00 to 2018-04-13 00:00:00
# Minor_axis axis: Open to TI_Q

# %% [markdown]
# ### Reindex the panel for having constant frequecncy for NN model
# ### Retiring this code

# %%
min_date=min(p3.major_axis)
max_date=max(p3.major_axis) + timedelta(days = 5)
idx=pd.date_range(min_date, max_date, freq="1d")
idx
# Out:
# DatetimeIndex(['2012-06-30', '2012-07-01', '2012-07-02', '2012-07-03',
#                '2012-07-04', '2012-07-05', '2012-07-06', '2012-07-07',
#                '2012-07-08', '2012-07-09',
#                ...
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18'],
#               dtype='datetime64[ns]', length=2119, freq='D')

# %%
p3=p3.reindex(major_axis=idx)
p3.major_axis
# Out:
# DatetimeIndex(['2012-06-30', '2012-07-01', '2012-07-02', '2012-07-03',
#                '2012-07-04', '2012-07-05', '2012-07-06', '2012-07-07',
#                '2012-07-08', '2012-07-09',
#                ...
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18'],
#               dtype='datetime64[ns]', length=2119, freq='D')

# %% [markdown]
# ### Fill empty cells using intrapolation

# %%
p3[p3.items[0]].head()
# Out:
#              Open    High     Low   Last   Close  Total Trade Quantity  \
# 2012-06-30    NaN     NaN     NaN    NaN     NaN                   NaN
# 2012-07-01    NaN     NaN     NaN    NaN     NaN                   NaN
# 2012-07-02  391.0  401.70  386.05  393.0  394.35              901205.0
# 2012-07-03  395.8  401.95  392.10  395.0  396.05              570933.0
# 2012-07-04  398.0  411.95  398.00  405.5  407.15             1210606.0
#
#             Turnover (Lacs)    Return  BSEVOL_Q  EQCAP_Q  ...   TAX_Q  BSEO_Q  \
# 2012-06-30              NaN       NaN       NaN      NaN  ...     NaN     NaN
# 2012-07-01              NaN       NaN       NaN      NaN  ...     NaN     NaN
# 2012-07-02          3567.37  0.011733       NaN      NaN  ...     NaN     NaN
# 2012-07-03          2264.21  0.004302       NaN      NaN  ...     NaN     NaN
# 2012-07-04          4936.54  0.027641       NaN      NaN  ...     NaN     NaN
#
#             FV_Q  OP_Q  DEP_Q  EBIDTSH1Q_Q  EBIDT_Q  EPS_Q  BSEL_Q  TI_Q
# 2012-06-30   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-01   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-02   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-03   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
# 2012-07-04   NaN   NaN    NaN          NaN      NaN    NaN     NaN   NaN
#
# [5 rows x 42 columns]

# %%
# Our counter program
def press_relase_counter(df,col_to_count, new_col_name):  

    counter=0
    counter_array=[]
    
    for i in df[col_to_count]:
        if pd.isnull(i):
            counter+=1
        else:
            counter=0 
        counter_array.append(counter)
    
    counter_se=pd.Series(counter_array)
    
    df[new_col_name]= counter_se.values
    
    return df


# Columns to use
# Financial Ratios
selected_r=[
'DEP_Q',
'DIVSH_Q',
'EBIDT_Q',
'EPS_Q',
'EQCAP_Q',
'ETR_Q',
'FV_Q',
'INT_Q',
'MCAP_Q',
'NP_Q',
'OEXPNS_Q',
'OI_Q',
'OP_Q',
'OPMSH_Q',
'OPSH1Q_Q',
'PBDT_Q',
'PBT_Q',
'REVSH_Q',
'SHARE_Q',
'SR_Q',
'TAX_Q',
'TI_Q',
]

# Data from prices
selected_p =[
    "Close",
    "Total Trade Quantity",
    "Turnover (Lacs)",
    "Return"
]

# Total Column
selected_col_total=selected_p+selected_r


# Reducing P3 to only selected columns 
p3=p3.loc[:, :, selected_col_total ]


# Addiding trime based varaibales 
# p3.loc[:,:,"day"]= 
p3.loc[:,:,"monthday"]=p3.major_axis.day
p3.loc[:,:,"month"]=p3.major_axis.month
p3.loc[:,:,"weekday"]=p3.major_axis.dayofweek+1


for item in p3.items:
    press_relase_counter(p3[item], 'TI_Q', "Counter")
    p3[item].interpolate(method="spline", order=1,axis=0, limit_direction="both", inplace=True)
    p3[item]["Ticker"]=str(item)

item = p3.items[0]
p3[item]
# Out:
#                  Close  Total Trade Quantity  Turnover (Lacs)    Return  \
# 2012-06-30  390.690315          1.561748e+06      6173.330444 -0.000053
# 2012-07-01  392.500086          1.231476e+06      4870.326766 -0.000053
# 2012-07-02  394.350000          9.012050e+05      3567.370000  0.011733
# 2012-07-03  396.050000          5.709330e+05      2264.210000  0.004302
# 2012-07-04  407.150000          1.210606e+06      4936.540000  0.027641
# 2012-07-05  422.700000          1.507657e+06      6287.990000  0.037481
# 2012-07-06  414.850000          8.112100e+05      3386.680000 -0.018746
# 2012-07-07  413.815339          7.563399e+05      3138.403738 -0.000056
# 2012-07-08  410.346855          7.014695e+05      2890.043603 -0.000057
# 2012-07-09  407.300000          6.465990e+05      2641.640000 -0.018367
# 2018-04-13    ...     31.543217  6.386559  190.624053 -5.366758  203.690212
# 2018-04-14    ...     31.588718  6.387605  190.939161 -5.445893  204.003344
# 2018-04-15    ...     31.634219  6.388651  191.254269 -5.525028  204.316477
# 2018-04-16    ...     31.679721  6.389697  191.569377 -5.604163  204.629609
# 2018-04-17    ...     31.725222  6.390743  191.884485 -5.683298  204.942742
# 2018-04-18    ...     31.770723  6.391789  192.199593 -5.762433  205.255874
#
#             monthday  month  weekday  Counter    Ticker
# 2012-06-30      30.0    6.0      6.0        1  NSE/ABAN
# 2012-07-01       1.0    7.0      7.0        2  NSE/ABAN
# 2012-07-02       2.0    7.0      1.0        3  NSE/ABAN
# 2012-07-03       3.0    7.0      2.0        4  NSE/ABAN
# 2012-07-04       4.0    7.0      3.0        5  NSE/ABAN
# 2012-07-05       5.0    7.0      4.0        6  NSE/ABAN
# 2012-07-06       6.0    7.0      5.0        7  NSE/ABAN
# 2012-07-07       7.0    7.0      6.0        8  NSE/ABAN
# 2012-07-08       8.0    7.0      7.0        9  NSE/ABAN
# 2012-07-09       9.0    7.0      1.0       10  NSE/ABAN
# 2012-07-10      10.0    7.0      2.0       11  NSE/ABAN
# 2012-07-11      11.0    7.0      3.0       12  NSE/ABAN
# 2012-07-12      12.0    7.0      4.0       13  NSE/ABAN
# 2012-07-13      13.0    7.0      5.0       14  NSE/ABAN
# 2012-07-14      14.0    7.0      6.0       15  NSE/ABAN
# 2012-07-15      15.0    7.0      7.0       16  NSE/ABAN
# 2012-07-16      16.0    7.0      1.0       17  NSE/ABAN
# 2012-07-17      17.0    7.0      2.0       18  NSE/ABAN
# 2012-07-18      18.0    7.0      3.0       19  NSE/ABAN
# 2012-07-19      19.0    7.0      4.0       20  NSE/ABAN
# 2012-07-20      20.0    7.0      5.0       21  NSE/ABAN
# 2012-07-21      21.0    7.0      6.0       22  NSE/ABAN
# 2012-07-22      22.0    7.0      7.0       23  NSE/ABAN
# 2012-07-23      23.0    7.0      1.0       24  NSE/ABAN
# 2012-07-24      24.0    7.0      2.0       25  NSE/ABAN
# 2012-07-25      25.0    7.0      3.0       26  NSE/ABAN
# 2012-07-26      26.0    7.0      4.0       27  NSE/ABAN
# 2012-07-27      27.0    7.0      5.0       28  NSE/ABAN
# 2012-07-28      28.0    7.0      6.0       29  NSE/ABAN
# 2012-07-29      29.0    7.0      7.0       30  NSE/ABAN
# ...              ...    ...      ...      ...       ...
# 2018-03-20      20.0    3.0      2.0       79  NSE/ABAN
# 2018-03-21      21.0    3.0      3.0       80  NSE/ABAN
# 2018-03-22      22.0    3.0      4.0       81  NSE/ABAN
# 2018-03-23      23.0    3.0      5.0       82  NSE/ABAN
# 2018-03-24      24.0    3.0      6.0       83  NSE/ABAN
# 2018-03-25      25.0    3.0      7.0       84  NSE/ABAN
# 2018-03-26      26.0    3.0      1.0       85  NSE/ABAN
# 2018-03-27      27.0    3.0      2.0       86  NSE/ABAN
# 2018-03-28      28.0    3.0      3.0       87  NSE/ABAN
# 2018-03-29      29.0    3.0      4.0       88  NSE/ABAN
# 2018-03-30      30.0    3.0      5.0       89  NSE/ABAN
# 2018-03-31      31.0    3.0      6.0       90  NSE/ABAN
# 2018-04-01       1.0    4.0      7.0       91  NSE/ABAN
# 2018-04-02       2.0    4.0      1.0       92  NSE/ABAN
# 2018-04-03       3.0    4.0      2.0       93  NSE/ABAN
# 2018-04-04       4.0    4.0      3.0       94  NSE/ABAN
# 2018-04-05       5.0    4.0      4.0       95  NSE/ABAN
# 2018-04-06       6.0    4.0      5.0       96  NSE/ABAN
# 2018-04-07       7.0    4.0      6.0       97  NSE/ABAN
# 2018-04-08       8.0    4.0      7.0       98  NSE/ABAN
# 2018-04-09       9.0    4.0      1.0       99  NSE/ABAN
# 2018-04-10      10.0    4.0      2.0      100  NSE/ABAN
# 2018-04-11      11.0    4.0      3.0      101  NSE/ABAN
# 2018-04-12      12.0    4.0      4.0      102  NSE/ABAN
# 2018-04-13      13.0    4.0      5.0      103  NSE/ABAN
# 2018-04-14      14.0    4.0      6.0      104  NSE/ABAN
# 2018-04-15      15.0    4.0      7.0      105  NSE/ABAN
# 2018-04-16      16.0    4.0      1.0      106  NSE/ABAN
# 2018-04-17      17.0    4.0      2.0      107  NSE/ABAN
# 2018-04-18      18.0    4.0      3.0      108  NSE/ABAN
#
# [2119 rows x 31 columns]

# %%
# Change datatype of cols to numeric for hot encoding 

# p3.loc[:,:,"Counter "]
list(p3.minor_axis)
# Out:
# ['Close',
#  'Total Trade Quantity',
#  'Turnover (Lacs)',
#  'Return',
#  'DEP_Q',
#  'DIVSH_Q',
#  'EBIDT_Q',
#  'EPS_Q',
#  'EQCAP_Q',
#  'ETR_Q',
#  'FV_Q',
#  'INT_Q',
#  'MCAP_Q',
#  'NP_Q',
#  'OEXPNS_Q',
#  'OI_Q',
#  'OP_Q',
#  'OPMSH_Q',
#  'OPSH1Q_Q',
#  'PBDT_Q',
#  'PBT_Q',
#  'REVSH_Q',
#  'SHARE_Q',
#  'SR_Q',
#  'TAX_Q',
#  'TI_Q',
#  'monthday',
#  'month',
#  'weekday']

# %%
p3[item].hist(bins=20, figsize=(20,20), xlabelsize=10)
# p3[item].to_csv("not_normal.csv")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f84b9e7efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84c5f48c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84c5f2ca10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b7cca590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84c002f350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84bafc7110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b80e2e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84bae9ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84bae57a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b84617d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84b841b790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b83d0950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b8406b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b83bdcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b8375e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84b8337090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b82ee250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b82a4410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b825d5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b8213790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84b824a950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b8203b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b81b9cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b8171e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b8136090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84b7c6c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b7c24410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b7bdc5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b7b94790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84b7bcb950>]],
#       dtype=object)

# %% [raw]
# tick=str(item).split("/")[1]
# period="Q"
# ratio="DIV_PCT"
# ratio_2="DIVSH"
#
#
# query1="DEB/"+tick+"_"+period+"_"+ratio
# query2="DEB/"+tick+"_"+period+"_"+ratio_2
#
# print tick
# data["d1"]=quandl.get(query1, column_index=1)
# data["d2"]=quandl.get(query2, column_index=1)
# data

# %% [markdown]
# 1. Merge all items by removing index (panel to dataframe)
# 2. Training Test

# %%
sector_name=w.kwargs["sector_name"]
panel_file_name="Data/"+sector_name+".csv"
    

with open(panel_file_name, 'w') as f:
    for item in p3.items:
        p3[item].to_csv(f, header=False)
